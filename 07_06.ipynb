# %% [markdown]
# <a href="https://colab.research.google.com/github/navyagona/python-practice/blob/main/07_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/navyagona/python-practice
# Out:
# Cloning into 'python-practice'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (1/1), done.

# %%
class Person:
    def __init__(self, name, age, address):
        self._name = name
        self._age = age
        self._address = address

    def display(self):
        print(f"Name: {self._name}, Age: {self._age}, Address: {self._address}")

    def get_name(self):
        return self._name

    def set_name(self, name):
        self._name = name

    def get_age(self):
        return self._age

    def set_age(self, age):
        self._age = age

    def get_address(self):
        return self._address

    def set_address(self, address):
        self._address = address


class Student(Person):
    def __init__(self, name, age, address, student_id):
        super().__init__(name, age, address)
        self.student_id = student_id
        self.courses = []

    def enroll(self, course):
        if course not in self.courses:
            self.courses.append(course)
            course.add_student(self)
            print(f"{self._name} has enrolled in {course.course_name}")

    def display(self):
        super().display()
        print(f"Student ID: {self.student_id}, Courses: {[course.course_name for course in self.courses]}")


class Teacher(Person):
    def __init__(self, name, age, address, employee_id):
        super().__init__(name, age, address)
        self.employee_id = employee_id
        self.courses = []

    def assign_course(self, course):
        if course not in self.courses:
            self.courses.append(course)
            course.set_teacher(self)
            print(f"{self._name} is assigned to teach {course.course_name}")

    def display(self):
        super().display()
        print(f"Employee ID: {self.employee_id}, Courses: {[course.course_name for course in self.courses]}")


class Course:
    def __init__(self, course_name, course_code):
        self.course_name = course_name
        self.course_code = course_code
        self.students = []
        self.teacher = None

    def add_student(self, student):
        if student not in self.students:
            self.students.append(student)

    def set_teacher(self, teacher):
        self.teacher = teacher

    def display(self):
        print(f"Course Name: {self.course_name}, Course Code: {self.course_code}")
        if self.teacher:
            print(f"Teacher: {self.teacher.get_name()}")
        if self.students:
            print(f"Students: {[student.get_name() for student in self.students]}")
        else:
            print("No students enrolled in this course.")


class university:
    def __init__(self, name):
        self.name = name
        self.students = []
        self.teachers = []
        self.courses = []

    def add_student(self, student):
        self.students.append(student)
        print(f"Student {student.get_name()} added to the university.")

    def add_teacher(self, teacher):
        self.teachers.append(teacher)
        print(f"Teacher {teacher.get_name()} added to the university.")

    def add_course(self, course):
        self.courses.append(course)
        print(f"Course {course.course_name} added to the university.")

    def display_students(self):
        print("university Students:")
        for student in self.students:
            student.display()

    def display_teachers(self):
        print("university Teachers:")
        for teacher in self.teachers:
            teacher.display()

    def display_courses(self):
        print("university Courses:")
        for course in self.courses:
            course.display()


university = university("LPU")

student1 = Student("Navya", 19, "phagwara", "101")
student2 = Student("Teja", 18, "ludiana", "102")
university.add_student(student1)
university.add_student(student2)

#teachers to theuniversity
teacher1 = Teacher("Mr.Rahul", 40, "jalandhar", "T01")
teacher2 = Teacher("Ms. smitha", 35, "chandigar", "T02")
university.add_teacher(teacher1)
university.add_teacher(teacher2)

#courses to the university
course1 = Course("Math 101", "MATH101")
course2 = Course("English 101", "ENG101")
university.add_course(course1)
university.add_course(course2)

# Enrolling students in courses
student1.enroll(course1)
student1.enroll(course2)
student2.enroll(course1)

# teachers to courses
teacher1.assign_course(course1)
teacher2.assign_course(course2)

# university information
university.display_students()
university.display_teachers()
university.display_courses()
# Out:
# Student Navya added to the university.
# Student Teja added to the university.
# Teacher Mr.Rahul added to the university.
# Teacher Ms. smitha added to the university.
# Course Math 101 added to the university.
# Course English 101 added to the university.
# Navya has enrolled in Math 101
# Navya has enrolled in English 101
# Teja has enrolled in Math 101
# Mr.Rahul is assigned to teach Math 101
# Ms. smitha is assigned to teach English 101
# university Students:
# Name: Navya, Age: 19, Address: phagwara
# Student ID: 101, Courses: ['Math 101', 'English 101']
# Name: Teja, Age: 18, Address: ludiana
# Student ID: 102, Courses: ['Math 101']
# university Teachers:
# Name: Mr.Rahul, Age: 40, Address: jalandhar
# Employee ID: T01, Courses: ['Math 101']
# Name: Ms. smitha, Age: 35, Address: chandigar
# Employee ID: T02, Courses: ['English 101']
# university Courses:
# Course Name: Math 101, Course Code: MATH101
# Teacher: Mr.Rahul
# Students: ['Navya', 'Teja']
# ...
